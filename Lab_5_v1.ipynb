# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform
from scipy import stats

# %%
data5 = pd.read_csv('Lab4_final.csv')

# %%
data5
# Out:
#       Unnamed: 0.1  Unnamed: 0 customer       state  customer lifetime value  \
# 0                0           0  DK49336     Arizona              4809.216960
# 1                1           1  KX64629  California              2228.525238
# 2                2           2  LZ68649  Washington             14947.917300
# 3                3           3  XL78013      Oregon             22332.439460
# 4                4           6  IW72280  California              5035.035257
# ...            ...         ...      ...         ...                      ...
# 9129          9129       10903  SU71163     Arizona              2771.663013
# 9130          9130       10904  QI63521      Nevada             19228.463620
# 9131          9131       10906  KX53892      Oregon              5259.444853
# 9132          9132       10907  TL39050     Arizona             23893.304100
# 9133          9133       10908  WA60547  California             11971.977650
#
# ...

# %%
data5
# Out:
#       Unnamed: 0.1  Unnamed: 0 customer       state  customer lifetime value  \
# 0                0           0  DK49336     Arizona              4809.216960
# 1                1           1  KX64629  California              2228.525238
# 2                2           2  LZ68649  Washington             14947.917300
# 3                3           3  XL78013      Oregon             22332.439460
# 4                4           6  IW72280  California              5035.035257
# ...            ...         ...      ...         ...                      ...
# 9129          9129       10903  SU71163     Arizona              2771.663013
# 9130          9130       10904  QI63521      Nevada             19228.463620
# 9131          9131       10906  KX53892      Oregon              5259.444853
# 9132          9132       10907  TL39050     Arizona             23893.304100
# 9133          9133       10908  WA60547  California             11971.977650
#
# ...

# %%
numerical = data5.select_dtypes(include=['float64', 'int64'])

# %%
numerical.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  customer lifetime value  income  \
# 0             0           0              4809.216960   48029
# 1             1           1              2228.525238       0
# 2             2           2             14947.917300   22139
#
#    monthly premium auto  months since last claim  \
# 0                    61                      7.0
# 1                    64                      3.0
# 2                   100                     34.0
#
#    months since policy inception  number of open complaints  \
# 0                             52                        0.0
# 1                             26                        0.0
# 2                             31                        0.0
#
#    number of policies  total claim amount  month
# 0                   9          292.800000      2
# 1                   1          744.924331      1
# 2                   2          480.000000      2

# %%
# X-y split

# %%
X = numerical.drop(['total claim amount'],axis = 1)
Y = numerical['total claim amount']

# %%
#Normalize (numerical)

# %%
#Original graphic 'customer lifetime value'
sns.histplot(numerical['customer lifetime value'])
plt.show()

# %%
data['customer_log'] = np.log(data['customer lifetime value'])
# Out:
# C:\Users\ines_\AppData\Local\Temp\ipykernel_17100\2950750114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['customer_log'] = np.log(data['customer lifetime value'])

# %%
#Normalized graphic 'customer lifetime value'
sns.histplot(numerical['customer_log'])
plt.show()

# %%
#Original graphic 'income'
sns.histplot(numerical['income'])
plt.show()

# %%
numerical['income_log'] = np.log(numerical['income'])
# Out:
# C:\Users\ines_\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#Normalize graphic 'income'
sns.histplot(numerical['income_log'])
plt.show()

# %%
#Original graphic 'monthly premium auto'
sns.histplot(numerical['monthly premium auto'])
plt.show()

# %%
stats.boxcox(data['monthly premium auto'])
# Out:
# (array([0.66775806, 0.6678576 , 0.6685089 , ..., 0.66811859, 0.66788824,
#         0.66884904]),
#  -1.4943309562196074)

# %%
arr1, lmbda = stats.boxcox(data['monthly premium auto'])

# %%
#Normalize graphic 'monthly premium auto'
sns.histplot(arr1)
plt.show()

# %%
#Original graphic 'months since last claim'
sns.histplot(numerical['months since last claim'])
plt.show()

# %%
stats.boxcox(data['months since last claim'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17100\3224842729.py in <module>
# ----> 1 stats.boxcox(data['months since last claim'])
#
# ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py in boxcox(x, lmbda, alpha, optimizer)
#    1088
#    1089     if np.any(x <= 0):
# -> 1090         raise ValueError("Data must be positive.")
#    1091
#    1092     # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#
# ValueError: Data must be positive.

# %%
numerical[numerical['months since last claim'] <= 0]
# Out:
#       Unnamed: 0.1  Unnamed: 0  customer lifetime value  income  \
# 108            108         125              3919.366722   66676
# 128            128         147             11981.984810   21514
# 130            130         150              5380.898636   55350
# 154            154         181             10144.309400   27231
# 180            180         211              8107.265330       0
# ...            ...         ...                      ...     ...
# 8995          8995       10743              7216.100311       0
# 9002          9002       10752              8693.649178   88294
# 9050          9050       10808              2790.227993   22974
# 9096          9096       10865             19606.359990       0
# 9133          9133       10908             11971.977650   64195
#
#       monthly premium auto  months since last claim  \
# 108                     97                      0.0
# 128                     62                      0.0
# ...

# %%
numerical['months_temp'] = np.where(numerical['months since last claim'] < 0, 0,numerical['months since last claim'])

# %%
numerical['months_temp'] = numerical['months_temp'].replace(0,numerical['months since last claim'].mean())

# %%
months, lmbda = stats.boxcox(numerical['months_temp'])

# %%
#Normalize graphic 'months since last claim'
sns.histplot(months)
plt.show()

# %%
#Original graphic 'months since policy inception'
sns.histplot(numerical['months since policy inception'])
plt.show()

# %%
numerical[numerical['months since policy inception'] <= 0]
# Out:
#       Unnamed: 0.1  Unnamed: 0  customer lifetime value  income  \
# 77              77          91              7048.384055   24030
# 91              91         107              3179.474225   65742
# 119            119         138              4620.390087       0
# 202            202         237              5318.896640   25134
# 276            276         328              4236.842920   14476
# ...            ...         ...                      ...     ...
# 8517          8517       10185             13891.676380   70725
# 8534          8534       10205             10248.898020   52693
# 8591          8591       10272              2748.933734   55964
# 8698          8698       10397              5780.182197   51066
# 8726          8726       10431             16909.927670   65620
#
#       monthly premium auto  months since last claim  \
# 77                     194                     14.0
# 91                      79                      6.0
# ...

# %%
numerical['months_pol_temp'] = np.where(numerical['months since policy inception'] < 0, 0,numerical['months since policy inception'])

# %%
numerical['months_pol_temp'] = numerical['months_pol_temp'].replace(0,numerical['months since policy inception'].mean())

# %%
monthspol, lmbda = stats.boxcox(numerical['months_pol_temp'])

# %%
#Normalize graphic 'months since policy inception'
sns.histplot(monthspol)
plt.show()

# %%
#Original graphic 'number of open complaints'
sns.histplot(numerical['number of open complaints'])
plt.show()

# %%
numerical['complaints_log'] = np.log(numerical['number of open complaints'])
# Out:
# C:\Users\ines_\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ines_\AppData\Local\Temp\ipykernel_17100\1483590316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical['complaints_log'] = np.log(numerical['number of open complaints'])

# %%
#Normalize graphic 'number of open complaints'
sns.histplot(numerical['complaints_log'])
plt.show()

# %%
#Original graphic 'number of policies'
sns.histplot(numerical['number of policies'])
plt.show()

# %%
iqr = np.percentile(numerical['number of policies'],75) - np.percentile(data['number of policies'],25)

# %%
iqr
# Out:
# 3.0

# %%
upper_limit = np.percentile(numerical['number of policies'],75) + iqr*1.5
lower_limit = np.percentile(numerical['number of policies'],25) - iqr*1.5

# %%
upper_limit
# Out:
# 8.5

# %%
lower_limit
# Out:
# -3.5

# %%
numerical = numerical[(numerical['number of policies'] > lower_limit) & (numerical ['number of policies'] < upper_limit)]

# %%
#Normalize graphic 'number of policies'
sns.histplot(numerical['number of policies'])
plt.show()

# %%
#Original graphic 'total claim amount'
sns.histplot(numerical['total claim amount'])
plt.show()

# %%
numerical['claim_log'] = np.log(numerical['total claim amount'])
# Out:
# C:\Users\ines_\AppData\Local\Temp\ipykernel_17100\2554798841.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical['claim_log'] = np.log(numerical['total claim amount'])

# %%
#Normalize graphic 'total claim amount'
sns.histplot(numerical['claim_log'])
plt.show()

# %%
data5.to_csv('Lab5_final.csv')
